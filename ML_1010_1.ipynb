# %%
k-NN과 naive Bayes  내일은 또 다른거

먼저 k-NN 이게 더 중요한 것 같아 (거리로분리)
 케이스 : 정형데이터의 행 , n차원의 공간에서 점과 대응    (유클리드 맨해튼거리? 인접한 이웃?)
 유사도 : 이걸 측정한다
 그림 보고 이해하기  ex) 가장 가까운 이웃 3개를 보고 주변이 부도가 안났으니 이것도 부도가 아니다
                     k가 짝수 인 경우 반반이 되면 이상해지므로 홀수가 되어야 한다 (주로 홀수로 선택이 좋다)
거리라는 개념을 정의하는 것이 중요(택시거리(맨해튼 거리) , 피타고라스(유클리드 거리)(스케일링 필수 (뭐가 많이 차이나면))(수치형 변수여야한다) , 염기서열다른거 등등)
여기서는 계산량이 많음 거리 다 계산해야한다
금융하는 사람들이 눈에 띄는 알고리즘이 부스팅과 knn이다
거리는 스케일링해야한다

나이브 베이즈 분류기 (확률로 분리)
  p(a) --> p(a|b) 새롭게 ????
  두 사건 a,b에 대해서 p(a and b)=p(a)p(b)이면 독립
  독립이면 쉬워진다
  p(홍길동|스팸) 스팸인거 중에 홍길동 몇 개 나왔어?

SVM
해석적?? 해석불가?? 해석은 모르겠고 잘 분류해줘

가장 먼거리의 기울기와 y절편이 최적의 선

높이를 줬더니 나누어짐 kernel trick

서포트벡터는 가장 가까운 점??

서포트백터의 특징 4가지
마진의 최대화
영향 덜 받는거
성능 개선 보다 정확한 분류가 우선인다
이상치의 처리는 무시 할 수 도 있다

내일은 SVM의 특징적인 파라미터 실습

xai를 활용하면 전망이 좋지 않을까??? 해석????
# Out:
#   File "<ipython-input-1-12bfa7f660d7>", line 6
#     그림 보고 이해하기  ex) 가장 가까운 이웃 3개를 보고 주변이 부도가 안났으니 이것도 부도가 아니다
#                   ^
# SyntaxError: unmatched ')'

# %%
인코딩은 글을 숫자로 바꿔주는거 (범주를 숫자로)

원핫인코딩(0과 1로만 사용) ( y,n에 대해 y는 101 n은 010 )
라벨인코딩(3개일때) ( 1012 같은거랑 )
