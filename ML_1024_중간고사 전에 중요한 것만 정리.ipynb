# %%
import pandas as pd
HDR = pd.read_csv( "HD.csv")
HDR.isnull().mean()
#HDR에 결측치가 있다-> HDR.PW.fillna( 어떤값 )
HDR.PW=HDR.PW.fillna( 180 )

from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaled = MinMaxScaler().fit_transform( HDR[["PW"]])

tmp = pd.get_dummies(HDR.CP)
import numpy as np
HDR.CP=np.argmax( tmp.values, axis=1 )
tmp2 = pd.get_dummies(HDR.CP)
HDR.BA=np.argmax( tmp2.values, axis=1 )
HDR.PW=scaled

from sklearn.model_selection import train_test_split
train, test= train_test_split( HDR, test_size=0.3, stratify=HDR.HD)

from sklearn.tree import DecisionTreeClassifier
#HD.csv, HD가 target, CP, BA, PW가 X변수
Y = HDR.HD
X = HDR[ ["CP", "BA", "PW"]  ]
dt = DecisionTreeClassifier()
dt.fit( X, Y ) #modeling
dt.predict(X) #predict
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c1f3510866cd> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 HDR = pd.read_csv( "HD.csv")
#       3 HDR.isnull().mean()
#       4 #HDR에 결측치가 있다-> HDR.PW.fillna( 어떤값 )
#       5 HDR.PW=HDR.PW.fillna( 180 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
import pandas as pd
HDR = pd.read_csv( "HD.csv")
HDR.isnull().mean()
#HDR에 결측치가 있다-> HDR.PW.fillna( 어떤값 )
HDR.PW=HDR.PW.fillna( 180 )

from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaled = MrinMaxScale().fit_transform( HDR[["PW"]])

tmp = pd.get_dummies(HDR.CP)
import numpy as np
HDR.CP=np.argmax( tmp.values, axis=1 )
tmp2 = pd.get_dummies(HDR.CP)
HDR.BA=np.argmax( tmp2.values, axis=1 )
HDR.PW=scaled

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( X, Y, test_size=0.2)

from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=2).fit( x_train , y_train )

dt.score( x_test, y_test )  #정분류율 (입력된 X,Y로 계산...)
pred = dt.predict( x_test ) #예측된 Y값을 출력 Y:실제 Y값
np.mean( pred == y_test )  #정분류율 계산

from sklearn.metrics import accuracy_score, classification_report
accuracy_score( pred, y_test)  #정분류율
print( classification_report( pred, y_test) )
# Out:
#               precision    recall  f1-score   support
#
#            N       1.00      1.00      1.00         1
#            Y       1.00      1.00      1.00         1
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %%
#import XGboost
from xgboost import XGBClassifier

#Defining XGB Classification model
clf = XGBClassifier()

# %%
#Importing packages from sklearn

from sklearn import preprocessing
from sklearn import model_selection
from sklearn import metrics

#defining a set of values as a dictionary for hyperparameters

param_grid = {
    "n_estimators":[100,200,300,400],
    "max_depth":[1,3,5,7],                                 #4개 4개 16가지
    #"reg_lambda":[.01,.1,.5] # 무시하자
}

#declaring GridSearchCV model

model = model_selection.GridSearchCV(
    estimator = clf,  #분류모형
    param_grid = param_grid,  #파라미터 범위
    scoring = 'accuracy',  #정분류율
    verbose = 10,
    n_jobs = 1,          # 계산하는 코어의 수 지정, 병렬 처리
    cv = 5         # 5-fold CV
) # 4 * 4 * 5 번 계산

#fitting values to the gridsearchcv model

model.fit(X,Y)
#printing the best possible values to enhance accuracy
print(model.best_params_)
print(model.best_estimator_) # best 모형
#printing the best score
print(model.best_score_)

# %%
import pandas as pd
HDR = pd.read_csv( "HD.csv")
HDR.isnull().mean()
#HDR에 결측치가 있다-> HDR.PW.fillna( 어떤값 )
HDR.PW=HDR.PW.fillna( 180 )

from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaled = MinMaxScaler().fit_transform( HDR[["PW"]])

tmp = pd.get_dummies(HDR.CP)
import numpy as np
HDR.CP=np.argmax( tmp.values, axis=1 )
tmp2 = pd.get_dummies(HDR.CP)
HDR.BA=np.argmax( tmp2.values, axis=1 )
HDR.PW=scaled

from sklearn.model_selection import train_test_split
train, test= train_test_split( HDR, test_size=0.3, stratify=HDR.HD)

from sklearn.tree import DecisionTreeClassifier
#HD.csv, HD가 target, CP, BA, PW가 X변수
Y = HDR.HD
X = HDR[ ["CP", "BA", "PW"]  ]
dt = DecisionTreeClassifier()
dt.fit( X, Y ) #modeling
dt.predict(X) #predict

import pandas as pd
HDR = pd.read_csv( "HD.csv")
HDR.isnull().mean()
#HDR에 결측치가 있다-> HDR.PW.fillna( 어떤값 )
HDR.PW=HDR.PW.fillna( 180 )

from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaled = MinMaxScaler().fit_transform( HDR[["PW"]])

tmp = pd.get_dummies(HDR.CP)
import numpy as np
HDR.CP=np.argmax( tmp.values, axis=1 )
tmp2 = pd.get_dummies(HDR.CP)
HDR.BA=np.argmax( tmp2.values, axis=1 )
HDR.PW=scaled

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( X, Y, test_size=0.1)
# Out:
#    CP  BA        PW
# 4   0   0  0.364706
