# %%
(linux, sql)
수업 시작
DT(디시젼 트리) -> 과적합, 안전성이 떨어진다

1. 원래 데이터
2. 배깅해서 랜덤 부분집합들로 나눈다       ex) 부분집합의 갯수가 1개이면 DT와 다를바 없다 부분집합의 갯수를 중요하다고 본다
3. DT 여러개가 된다 포레스트
4. ensemble처럼 하나의 모형

예측값은 100개, Y가 95 , N가 5 이면 Y라고 따른다, 다수를 따른다 (majority voting)

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, random_state=42) # stratify : target

tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
tree.score(X_test, y_test)

from sklearn.ensemble import RandomForestClassifier
rf  = RandomForestClassifier( n_estimators=100 )  #n_estimators=500을 넣어서 500개의 부분집합들을 넣어서 적용한다???
rf.fit(X_train, y_train)                              # rf.n_estimators  100개의 부분집합을 랜덤으로 만든다?? 디폴트값은 100이다??
rf.score(X_test, y_test)
rf.predict(X_test)
y_test == rf.predict(X_test)
np.mean(y_test == rf.predict(X_test))

from sklearn.metrics import classification_report
# print( classification_report(y_test == rf.predict(X_test)))???????????

# %%
만약 x축이 n_estimators이고 y축이 정분률이라고 하면 적당한 값에 수렴하는데 100개나 500개나 비슷하면 100개하는게 좋지 500개가 더 정확할지라도 가성비를 따지면 100개가 더 좋다??? (가성비있는 파라미터를 찾는 것이 가장 중요하다)

랜덤포레스트의 배깅에서     데이터의 다양한 경우를 반영할 수 있도록 보완(즉 안정성이 좋아 진다)    DT의 취약점 보완한다
랜덤포레스트(RF)가 은근 성능이 좋다
나중에 boosting 3가지 배울 것인데 이거 좋다
